# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
1 + 1
# Out:
# 2

# %%
# Esse é um comentário em Python

# Multiplicação

2 * 2
# Out:
# 4

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
# Criando uma variável do tipo string
frase = "Python para análise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a análise de dados'

# %%
frase[:17]
# Out:
# 'Python para análi'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase = frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.title()
# Out:
# 'Python Para Análise De Dados'

# %%
frase.replace("frases", "Python")
# Out:
# 'Python para análise de dados'

# %%
frase.replace("Python", "frases")
# Out:
# 'frases para análise de dados'
