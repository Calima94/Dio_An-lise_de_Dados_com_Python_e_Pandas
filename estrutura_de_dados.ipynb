# %% [markdown]
# # Curso Python Para Análise de dados - Fernanda Santos

# %% [markdown]
# ## Estrutura de dados

# %% [markdown]
# ### Listas

# %%
# Criando uma lista chamada animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro", "gato", 12345, 6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
# Imprimindo o primeiro elemento da lista
animais[0]
# Out:
# 'cachorro'

# %%
# Imprimindo o 4 elemento da lista
animais[3]
# Out:
# 6.5

# %%
#Substituindo o primeiro elemento da lista
animais[0] = "papagaio"

# %%
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
# Removendo gato da lista
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500, 30, 300, 80, 10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leão")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leão']

# %%
animais.extend(["cobra", 6])

# %%
animais.count("leão")
# Out:
# 1

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %% [markdown]
# ### Tuplas

# %%
# As tuplas usam parêntesis com sintaxe
tp = ("Banana", "Maça", 10, 50)

# %%
# retornando o primeiro elemento
tp[0]
# Out:
# 'Banana'

# %%
#Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
# tipo de erro tentando atribuir valor a tupla
#tp[0] = "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-9264cd18bf8a> in <module>
#       1 #Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
# ----> 2 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maça")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maça')

# %% [markdown]
# ### Dicionários

# %%
#Para criar um dicionário utilizamos as {}
dc = {"Maça": 20, "Banana": 10, "Laranja": 15, "Uva": 5} # Dicionário trabalham com o conceito de chave e valor

# %%
#Acessando o valor de um dicionário através da chave
dc["Maça"] = 25
dc
# Out:
# {'Maça': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Maça', 'Banana', 'Laranja', 'Uva'])

# %%
#Retornando os valores do dicionário
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
#Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault("Limão", 22)
# Out:
# 22
